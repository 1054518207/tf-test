# %% [markdown]
# ## 3.10. 多层感知机的简洁实现
# 下面我们使用`Tensorflow`来实现上一节中的多层感知机。首先导入所需的包或模块。

# %%
import tensorflow as tf
from tensorflow import keras

# %% [markdown]
# ### 3.10.1. 定义模型
# 和softmax回归唯一的不同在于，我们多加了一个全连接层作为隐藏层。它的隐藏单元个数为256，并使用ReLU函数作为激活函数。

# %%
model = keras.Sequential()
model.add(keras.layers.Flatten(input_shape=(28,28)))
model.add(keras.layers.Dense(256, activation='relu'))
model.add(keras.layers.Dense(10,activation='softmax'))

# %% [markdown]
# ### 3.10.2. 训练模型
# 我们使用与“softmax回归的简洁实现”一节中训练softmax回归几乎相同的步骤来读取数据并训练模型。

# %%
batch_size = 256
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
train_images = tf.cast(train_images,dtype=tf.float32)/255.0
test_images = tf.cast(test_images,dtype=tf.float32)/255.0

model.compile(optimizer=tf.keras.optimizers.SGD(learning_rate=0.5),loss='sparse_categorical_crossentropy',metrics=['accuracy'])
model.fit(train_images,train_labels,batch_size,epochs=5,validation_data=[test_images,test_labels])
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 2s 34us/sample - loss: 0.7502 - accuracy: 0.7276 - val_loss: 0.6703 - val_accuracy: 0.7499
# Epoch 2/5
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.4869 - accuracy: 0.8206 - val_loss: 0.4500 - val_accuracy: 0.8392
# Epoch 3/5
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.4119 - accuracy: 0.8490 - val_loss: 0.5119 - val_accuracy: 0.8171
# Epoch 4/5
# 60000/60000 [==============================] - 2s 30us/sample - loss: 0.3815 - accuracy: 0.8593 - val_loss: 0.5554 - val_accuracy: 0.7994
# Epoch 5/5
# 60000/60000 [==============================] - 2s 29us/sample - loss: 0.3649 - accuracy: 0.8648 - val_loss: 0.5358 - val_accuracy: 0.8039

# %% [markdown]
# ### 3.10.3. 小结
# - 通过`Keras`可以更简洁地实现多层感知机。
